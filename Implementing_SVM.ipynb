# %% [markdown]
# <a href="https://colab.research.google.com/github/MusabDemirrr/support-vector-machine-implementation/blob/main/Implementing_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
class SupportVectorMachine():
  def __init__(self,learning_rate,epochs,lambda_paramater):

    self.learning_rate = learning_rate
    self.epochs = epochs
    self.lambda_paramater = lambda_paramater

  def train(self,X,Y):

    self.number_of_data_points,self.number_of_features = X.shape

    self.X = X
    self.Y = Y

    self.bias = 0
    self.weights = np.zeros(self.number_of_features)

    for _ in range(self.epochs):
      self.update_weights()




  def update_weights(self):
    y_label = np.where(self.Y > 0,1,-1)

    for index,x_i in enumerate(self.X):

      if( y_label[index] * (x_i.dot(self.weights) - self.bias) >= 1 ):

        dw = 2 * self.weights * self.lambda_paramater
        db = 0

      else:
        dw = 2 * self.lambda_paramater * self.weights - np.dot(x_i,y_label[index])
        db = y_label[index]

      self.weights = self.weights - dw*self.learning_rate
      self.bias = self.bias - db*self.learning_rate







  def prediction(self,X):
    result = X.dot(self.weights) - self.bias

    y_hats = np.where(result >= 0 , 1,0)
    return y_hats

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
diabetes_data = pd.read_csv("/content/diabetes (2).csv")

# %%
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  ...   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72             35  ...  33.6                     0.627   50        1
# 1            1       85             66             29  ...  26.6                     0.351   31        0
# 2            8      183             64              0  ...  23.3                     0.672   32        1
# 3            1       89             66             23  ...  28.1                     0.167   21        0
# 4            0      137             40             35  ...  43.1                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
diabetes_data.shape
# Out:
# (768, 9)

# %%
input_data = diabetes_data.drop("Outcome",axis=1)
output_data = diabetes_data["Outcome"]

# %%
input_data
# Out:
#      Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0              6      148             72  ...  33.6                     0.627   50
# 1              1       85             66  ...  26.6                     0.351   31
# 2              8      183             64  ...  23.3                     0.672   32
# 3              1       89             66  ...  28.1                     0.167   21
# 4              0      137             40  ...  43.1                     2.288   33
# ..           ...      ...            ...  ...   ...                       ...  ...
# 763           10      101             76  ...  32.9                     0.171   63
# 764            2      122             70  ...  36.8                     0.340   27
# 765            5      121             72  ...  26.2                     0.245   30
# 766            1      126             60  ...  30.1                     0.349   47
# ...

# %%
output_data
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
diabetes_data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
scaler = StandardScaler()
scaler.fit(input_data)
input_data = scaler.transform(input_data)

# %%
print(train_input.shape)
print(test_input.shape)
print(train_output.shape)
print(test_output.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %%
train_input,test_input,train_output,test_output = train_test_split(input_data,output_data,test_size=0.2,random_state=4)

# %%
model = SupportVectorMachine(learning_rate=0.02,lambda_paramater=0.01,epochs=2000)

# %%
model.train(train_input,train_output)

# %%
y_test_prediction = model.prediction(test_input)
accuracy = accuracy_score(test_output,y_test_prediction)

# %%
print(f"Acucuracy score is %{100*accuracy}")
# Out:
# Acucuracy score is %81.81818181818183
